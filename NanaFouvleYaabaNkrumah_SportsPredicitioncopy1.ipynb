# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading the data files and cleaning them

# %%
# Load the datasets
male_players_training = pd.read_csv('male_players (legacy).csv')
players_22_testing= pd.read_csv('players_22.csv')
# Out:
# C:\Users\edusa\AppData\Local\Temp\ipykernel_25032\794809613.py:2: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   male_players_training = pd.read_csv('male_players (legacy).csv')
# C:\Users\edusa\AppData\Local\Temp\ipykernel_25032\794809613.py:3: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_22_testing= pd.read_csv('players_22.csv')

# %%
male_players_training
# Out:
#         player_id                                        player_url  \
# 0          158023                /player/158023/lionel-messi/150002
# 1           20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2            9014                  /player/9014/arjen-robben/150002
# 3           41236           /player/41236/zlatan-ibrahimovic/150002
# 4          167495                /player/167495/manuel-neuer/150002
# ...           ...                                               ...
# 161578     269011                   /player/269011/ziye-zhao/230002
# 161579     269019                   /player/269019/junjie-wu/230002
# 161580     271093               /player/271093/kailin-barlow/230002
# 161581     271555               /player/271555/gideon-tetteh/230002
# 161582     271608           /player/271608/aqeel-al-dhafeeri/230002
#
#         fifa_version  fifa_update fifa_update_date         short_name  \
# 0                 15            2       2014-09-18           L. Messi
# 1                 15            2       2014-09-18  Cristiano Ronaldo
# 2                 15            2       2014-09-18          A. Robben
# 3                 15            2       2014-09-18     Z. Ibrahimović
# 4                 15            2       2014-09-18           M. Neuer
# ...              ...          ...              ...                ...
# 161578            23            2       2022-09-26          Zhao Ziye
# 161579            23            2       2022-09-26          Wu Junjie
# 161580            23            2       2022-09-26          K. Barlow
# 161581            23            2       2022-09-26          G. Tetteh
# 161582            23            2       2022-09-26     A. Al Dhafeeri
#
#                                   long_name player_positions  overall  \
# 0            Lionel Andrés Messi Cuccittini               CF       93
# 1       Cristiano Ronaldo dos Santos Aveiro           LW, LM       92
# 2                              Arjen Robben       RM, LM, RW       90
# 3                        Zlatan Ibrahimović               ST       90
# 4                        Manuel Peter Neuer               GK       90
# ...                                     ...              ...      ...
# 161578                                  赵梓业               RW       46
# 161579                                  吴俊杰               LB       46
# 161580                        Kailin Barlow              CDM       46
# 161581                        Gideon Tetteh           RW, LW       46
# 161582                    Aqeel Al Dhafeeri               CB       46
#
#         potential  ...   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 0              95  ...  62+3  62+3  62+3  54+3  45+3  45+3  45+3  54+3  15+3
# 1              92  ...  63+3  63+3  63+3  57+3  52+3  52+3  52+3  57+3  16+3
# 2              90  ...  64+3  64+3  64+3  55+3  46+3  46+3  46+3  55+3  14+3
# 3              90  ...  65+3  65+3  61+3  56+3  55+3  55+3  55+3  56+3  17+3
# 4              90  ...  40+3  40+3  36+3  36+3  38+3  38+3  38+3  36+3  87+3
# ...           ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 161578         61  ...  32+2  32+2  37+2  36+2  31+2  31+2  31+2  36+2  14+2
# 161579         58  ...  41+2  41+2  43+2  44+2  48+2  48+2  48+2  44+2  15+2
# 161580         58  ...  45+2  45+2  47+2  47+2  46+2  46+2  46+2  47+2  14+2
# 161581         70  ...  30+2  30+2  34+2  32+2  28+2  28+2  28+2  32+2  15+2
# 161582         63  ...  40+2  40+2  39+2  41+2  46+2  46+2  46+2  41+2  13+2
#
#                                           player_face_url
# 0       https://cdn.sofifa.net/players/158/023/15_120.png
# 1       https://cdn.sofifa.net/players/020/801/15_120.png
# 2       https://cdn.sofifa.net/players/009/014/15_120.png
# 3       https://cdn.sofifa.net/players/041/236/15_120.png
# 4       https://cdn.sofifa.net/players/167/495/15_120.png
# ...                                                   ...
# 161578  https://cdn.sofifa.net/players/269/011/23_120.png
# 161579  https://cdn.sofifa.net/players/269/019/23_120.png
# 161580  https://cdn.sofifa.net/players/271/093/23_120.png
# 161581  https://cdn.sofifa.net/players/271/555/23_120.png
# 161582  https://cdn.sofifa.net/players/271/608/23_120.png
#
# [161583 rows x 110 columns]

# %%
male_players_training.columns
# Out:
# Index(['player_id', 'player_url', 'fifa_version', 'fifa_update',
#        'fifa_update_date', 'short_name', 'long_name', 'player_positions',
#        'overall', 'potential',
#        ...
#        'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk',
#        'player_face_url'],
#       dtype='object', length=110)

# %%
male_players_training= male_players_training.drop(['player_face_url' , 'player_url','fifa_version', 'fifa_update','fifa_update_date','wage_eur'  ] , axis = 1)

# %%
#turning id into int
male_players_training['player_id'] = male_players_training['player_id'].astype(int)

# %%
male_players_training.columns
# Out:
# Index(['player_id', 'short_name', 'long_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'age', 'dob', 'height_cm',
#        ...
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk'],
#       dtype='object', length=104)

# %%
#dropping the date of birth
male_players_training= male_players_training.drop(['dob','player_id', 'short_name', 'long_name', 'player_positions']  , axis = 1)

# %%
male_players_training.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'age', 'height_cm', 'weight_kg',
#        'league_id', 'league_name', 'league_level', 'club_team_id', 'club_name',
#        'club_position', 'club_jersey_number', 'club_loaned_from',
#        'club_joined_date', 'club_contract_valid_until_year', 'nationality_id',
#        'nationality_name', 'nation_team_id', 'nation_position',
#        'nation_jersey_number', 'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'player_traits', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed',
#        'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
#        'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb', 'gk'],
#       dtype='object')

# %% [markdown]
# ##### Reasons For Dropping Columns

# %% [markdown]
# I dropped the following columns because when I read the descriptions of what they meant on Kaggle. I realised that they will not affect the prediction of a player's overall rating given a profile of the player

# %%
male_players_training.drop(['league_id', 'league_name', 'league_level' , 'league_id' , 'club_team_id', 'club_name', 'club_position', 'club_jersey_number', 'club_loaned_from', 'club_joined_date', 'club_contract_valid_until_year', 'nationality_id', 'nationality_name',
                            'nation_team_id', 'nation_position', 'nation_jersey_number', 'release_clause_eur', 'club_contract_valid_until_year','nationality_id',
        'nation_team_id', 'nation_position', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 
    'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb',
    'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk'
  ], axis= 1, inplace=True)

# %%
male_players_training.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'age', 'height_cm', 'weight_kg',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'player_tags', 'player_traits', 'pace', 'shooting', 'passing',
#        'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed'],
#       dtype='object')

# %%
male_players_training
# Out:
#         overall  potential    value_eur  age  height_cm  weight_kg  \
# 0            93         95  100500000.0   27        169         67
# 1            92         92   79000000.0   29        185         80
# 2            90         90   54500000.0   30        180         80
# 3            90         90   52500000.0   32        195         95
# 4            90         90   63500000.0   28        193         92
# ...         ...        ...          ...  ...        ...        ...
# 161578       46         61     110000.0   18        180         73
# 161579       46         58     110000.0   19        188         83
# 161580       46         58     110000.0   19        181         73
# 161581       46         70     150000.0   17        175         68
# 161582       46         63     110000.0   17        180         70
#
#        preferred_foot  weak_foot  skill_moves  international_reputation  ...  \
# 0                Left          3            4                         5  ...
# 1               Right          4            5                         5  ...
# 2                Left          2            4                         5  ...
# 3               Right          4            4                         5  ...
# 4               Right          4            1                         5  ...
# ...               ...        ...          ...                       ...  ...
# 161578          Right          3            2                         1  ...
# 161579           Left          3            2                         1  ...
# 161580          Right          2            2                         1  ...
# 161581          Right          3            2                         1  ...
# 161582          Right          3            2                         1  ...
#
#        mentality_composure defending_marking_awareness  \
# 0                      NaN                          25
# 1                      NaN                          22
# 2                      NaN                          29
# 3                      NaN                          25
# 4                      NaN                          25
# ...                    ...                         ...
# 161578                40.0                          23
# 161579                35.0                          50
# 161580                35.0                          36
# 161581                43.0                          19
# 161582                30.0                          50
#
#        defending_standing_tackle defending_sliding_tackle goalkeeping_diving  \
# 0                             21                       20                  6
# 1                             31                       23                  7
# 2                             26                       26                 10
# 3                             41                       27                 13
# 4                             25                       25                 87
# ...                          ...                      ...                ...
# 161578                        21                       25                  9
# 161579                        51                       45                  6
# 161580                        45                       50                  8
# 161581                        17                       14                 13
# 161582                        45                       42                 13
#
#         goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         11                   15                       14
# 1                         11                   15                       14
# 2                          8                   11                        5
# 3                         15                   10                        9
# 4                         85                   92                       90
# ...                      ...                  ...                      ...
# 161578                    13                   13                       12
# 161579                    14                    8                       13
# 161580                     9                    7                       14
# 161581                    12                   14                        7
# 161582                     7                    6                        6
#
#         goalkeeping_reflexes  goalkeeping_speed
# 0                          8                NaN
# 1                         11                NaN
# 2                         15                NaN
# 3                         12                NaN
# 4                         86               60.0
# ...                      ...                ...
# 161578                     7                NaN
# 161579                    14                NaN
# 161580                     9                NaN
# 161581                    13                NaN
# 161582                    14                NaN
#
# [161583 rows x 56 columns]

# %%
male_players_training.info() #to check if there are missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161583 entries, 0 to 161582
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   overall                      161583 non-null  int64
#  1   potential                    161583 non-null  int64
#  2   value_eur                    159530 non-null  float64
#  3   age                          161583 non-null  int64
#  4   height_cm                    161583 non-null  int64
#  5   weight_kg                    161583 non-null  int64
#  6   preferred_foot               161583 non-null  object
#  7   weak_foot                    161583 non-null  int64
#  8   skill_moves                  161583 non-null  int64
#  9   international_reputation     161583 non-null  int64
#  10  work_rate                    161583 non-null  object
#  11  body_type                    161583 non-null  object
#  12  real_face                    161583 non-null  object
#  13  player_tags                  12663 non-null   object
#  14  player_traits                73150 non-null   object
#  15  pace                         143614 non-null  float64
#  16  shooting                     143614 non-null  float64
#  17  passing                      143614 non-null  float64
#  18  dribbling                    143614 non-null  float64
#  19  defending                    143614 non-null  float64
#  20  physic                       143614 non-null  float64
#  21  attacking_crossing           161583 non-null  int64
#  22  attacking_finishing          161583 non-null  int64
#  23  attacking_heading_accuracy   161583 non-null  int64
#  24  attacking_short_passing      161583 non-null  int64
#  25  attacking_volleys            161583 non-null  int64
#  26  skill_dribbling              161583 non-null  int64
#  27  skill_curve                  161583 non-null  int64
#  28  skill_fk_accuracy            161583 non-null  int64
#  29  skill_long_passing           161583 non-null  int64
#  30  skill_ball_control           161583 non-null  int64
#  31  movement_acceleration        161583 non-null  int64
#  32  movement_sprint_speed        161583 non-null  int64
#  33  movement_agility             161583 non-null  int64
#  34  movement_reactions           161583 non-null  int64
#  35  movement_balance             161583 non-null  int64
#  36  power_shot_power             161583 non-null  int64
#  37  power_jumping                161583 non-null  int64
#  38  power_stamina                161583 non-null  int64
#  39  power_strength               161583 non-null  int64
#  40  power_long_shots             161583 non-null  int64
#  41  mentality_aggression         161583 non-null  int64
#  42  mentality_interceptions      161583 non-null  int64
#  43  mentality_positioning        161583 non-null  int64
#  44  mentality_vision             161583 non-null  int64
#  45  mentality_penalties          161583 non-null  int64
#  46  mentality_composure          128722 non-null  float64
#  47  defending_marking_awareness  161583 non-null  int64
#  48  defending_standing_tackle    161583 non-null  int64
#  49  defending_sliding_tackle     161583 non-null  int64
#  50  goalkeeping_diving           161583 non-null  int64
#  51  goalkeeping_handling         161583 non-null  int64
#  52  goalkeeping_kicking          161583 non-null  int64
#  53  goalkeeping_positioning      161583 non-null  int64
#  54  goalkeeping_reflexes         161583 non-null  int64
#  55  goalkeeping_speed            17969 non-null   float64
# dtypes: float64(9), int64(41), object(6)
# memory usage: 69.0+ MB

# %%
#dropping the columns that have 30% missing values
L = []
L_less = []
for i in male_players_training.columns:
    if(male_players_training[i].isnull().sum()<(0.3*male_players_training.shape[0])):
        L.append(i)
    else:
        L_less.append(i)

# %%
#separating numeric and non-numeric
numeric_data = male_players_training.select_dtypes(include= np.number)
non_numeric = male_players_training.select_dtypes(exclude= np.number)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imp = IterativeImputer(max_iter=20, tol=1e-1, random_state=0)

# Fit and transform the data
numeric_data_imputed = imp.fit_transform(numeric_data)

# Round the imputed data and convert it back to a DataFrame
numeric_data = pd.DataFrame(np.round(numeric_data_imputed), columns=numeric_data.columns)
# Out:
# C:\Users\edusa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
numeric_data
# Out:
#         overall  potential    value_eur   age  height_cm  weight_kg  \
# 0          93.0       95.0  100500000.0  27.0      169.0       67.0
# 1          92.0       92.0   79000000.0  29.0      185.0       80.0
# 2          90.0       90.0   54500000.0  30.0      180.0       80.0
# 3          90.0       90.0   52500000.0  32.0      195.0       95.0
# 4          90.0       90.0   63500000.0  28.0      193.0       92.0
# ...         ...        ...          ...   ...        ...        ...
# 161578     46.0       61.0     110000.0  18.0      180.0       73.0
# 161579     46.0       58.0     110000.0  19.0      188.0       83.0
# 161580     46.0       58.0     110000.0  19.0      181.0       73.0
# 161581     46.0       70.0     150000.0  17.0      175.0       68.0
# 161582     46.0       63.0     110000.0  17.0      180.0       70.0
#
#         weak_foot  skill_moves  international_reputation  pace  ...  \
# 0             3.0          4.0                       5.0  93.0  ...
# 1             4.0          5.0                       5.0  93.0  ...
# 2             2.0          4.0                       5.0  93.0  ...
# 3             4.0          4.0                       5.0  76.0  ...
# 4             4.0          1.0                       5.0  60.0  ...
# ...           ...          ...                       ...   ...  ...
# 161578        3.0          2.0                       1.0  63.0  ...
# 161579        3.0          2.0                       1.0  55.0  ...
# 161580        2.0          2.0                       1.0  65.0  ...
# 161581        3.0          2.0                       1.0  55.0  ...
# 161582        3.0          2.0                       1.0  61.0  ...
#
#         mentality_composure  defending_marking_awareness  \
# 0                      93.0                         25.0
# 1                      92.0                         22.0
# 2                      90.0                         29.0
# 3                      93.0                         25.0
# 4                      59.0                         25.0
# ...                     ...                          ...
# 161578                 40.0                         23.0
# 161579                 35.0                         50.0
# 161580                 35.0                         36.0
# 161581                 43.0                         19.0
# 161582                 30.0                         50.0
#
#         defending_standing_tackle  defending_sliding_tackle  \
# 0                            21.0                      20.0
# 1                            31.0                      23.0
# 2                            26.0                      26.0
# 3                            41.0                      27.0
# 4                            25.0                      25.0
# ...                           ...                       ...
# 161578                       21.0                      25.0
# 161579                       51.0                      45.0
# 161580                       45.0                      50.0
# 161581                       17.0                      14.0
# 161582                       45.0                      42.0
#
#         goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                      6.0                  11.0                 15.0
# 1                      7.0                  11.0                 15.0
# 2                     10.0                   8.0                 11.0
# 3                     13.0                  15.0                 10.0
# 4                     87.0                  85.0                 92.0
# ...                    ...                   ...                  ...
# 161578                 9.0                  13.0                 13.0
# 161579                 6.0                  14.0                  8.0
# 161580                 8.0                   9.0                  7.0
# 161581                13.0                  12.0                 14.0
# 161582                13.0                   7.0                  6.0
#
#         goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed
# 0                          14.0                   8.0               91.0
# 1                          14.0                  11.0               91.0
# 2                           5.0                  15.0               91.0
# 3                           9.0                  12.0               74.0
# 4                          90.0                  86.0               60.0
# ...                         ...                   ...                ...
# 161578                     12.0                   7.0               63.0
# 161579                     13.0                  14.0               54.0
# 161580                     14.0                   9.0               64.0
# 161581                      7.0                  13.0               55.0
# 161582                      6.0                  14.0               60.0
#
# [161583 rows x 50 columns]

# %%
numeric_data.head()
# Out:
#    overall  potential    value_eur   age  height_cm  weight_kg  weak_foot  \
# 0     93.0       95.0  100500000.0  27.0      169.0       67.0        3.0
# 1     92.0       92.0   79000000.0  29.0      185.0       80.0        4.0
# 2     90.0       90.0   54500000.0  30.0      180.0       80.0        2.0
# 3     90.0       90.0   52500000.0  32.0      195.0       95.0        4.0
# 4     90.0       90.0   63500000.0  28.0      193.0       92.0        4.0
#
#    skill_moves  international_reputation  pace  ...  mentality_composure  \
# 0          4.0                       5.0  93.0  ...                 93.0
# 1          5.0                       5.0  93.0  ...                 92.0
# 2          4.0                       5.0  93.0  ...                 90.0
# 3          4.0                       5.0  76.0  ...                 93.0
# 4          1.0                       5.0  60.0  ...                 59.0
#
#    defending_marking_awareness  defending_standing_tackle  \
# 0                         25.0                       21.0
# 1                         22.0                       31.0
# 2                         29.0                       26.0
# 3                         25.0                       41.0
# 4                         25.0                       25.0
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                      20.0                 6.0                  11.0
# 1                      23.0                 7.0                  11.0
# 2                      26.0                10.0                   8.0
# 3                      27.0                13.0                  15.0
# 4                      25.0                87.0                  85.0
#
#    goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                 15.0                     14.0                   8.0
# 1                 15.0                     14.0                  11.0
# 2                 11.0                      5.0                  15.0
# 3                 10.0                      9.0                  12.0
# 4                 92.0                     90.0                  86.0
#
#    goalkeeping_speed
# 0               91.0
# 1               91.0
# 2               91.0
# 3               74.0
# 4               60.0
#
# [5 rows x 50 columns]

# %%
numeric_data.iloc[30:50,:]
# Out:
#     overall  potential   value_eur   age  height_cm  weight_kg  weak_foot  \
# 30     86.0       90.0  27000000.0  22.0      199.0       88.0        3.0
# 31     86.0       92.0  35000000.0  22.0      180.0       75.0        3.0
# 32     85.0       85.0  18000000.0  32.0      196.0       90.0        3.0
# 33     85.0       85.0  21000000.0  30.0      173.0       75.0        3.0
# 34     85.0       87.0  27000000.0  26.0      184.0       79.0        4.0
# 35     85.0       86.0  21000000.0  27.0      188.0       78.0        1.0
# 36     85.0       86.0  21000000.0  25.0      190.0       81.0        3.0
# 37     85.0       86.0  27000000.0  26.0      174.0       63.0        3.0
# 38     85.0       87.0  25500000.0  27.0      184.0       71.0        3.0
# 39     85.0       87.0  26500000.0  25.0      188.0       81.0        4.0
# 40     85.0       87.0  23000000.0  27.0      180.0       75.0        4.0
# 41     85.0       88.0  23000000.0  24.0      182.0       78.0        5.0
# 42     85.0       86.0  21000000.0  25.0      192.0       90.0        4.0
# 43     85.0       89.0  20000000.0  25.0      189.0       73.0        3.0
# 44     85.0       91.0  21000000.0  22.0      176.0       72.0        4.0
# 45     84.0       84.0  16500000.0  33.0      185.0       84.0        2.0
# 46     84.0       84.0   6000000.0  35.0      177.0       68.0        4.0
# 47     84.0       84.0  11500000.0  32.0      183.0       77.0        4.0
# 48     84.0       84.0  14500000.0  30.0      185.0       83.0        4.0
# 49     84.0       84.0  17500000.0  29.0      186.0       76.0        2.0
#
#     skill_moves  international_reputation  pace  ...  mentality_composure  \
# 30          1.0                       3.0  49.0  ...                 52.0
# 31          4.0                       4.0  79.0  ...                 85.0
# 32          1.0                       4.0  49.0  ...                 57.0
# 33          3.0                       3.0  86.0  ...                 88.0
# 34          4.0                       4.0  84.0  ...                 83.0
# 35          1.0                       3.0  64.0  ...                 53.0
# 36          2.0                       3.0  53.0  ...                 83.0
# 37          4.0                       3.0  74.0  ...                 84.0
# 38          3.0                       4.0  79.0  ...                 81.0
# 39          3.0                       3.0  82.0  ...                 80.0
# 40          3.0                       4.0  78.0  ...                 85.0
# 41          3.0                       4.0  58.0  ...                 87.0
# 42          3.0                       4.0  77.0  ...                 78.0
# 43          3.0                       4.0  56.0  ...                 85.0
# 44          4.0                       3.0  80.0  ...                 82.0
# 45          1.0                       4.0  64.0  ...                 53.0
# 46          2.0                       4.0  43.0  ...                 90.0
# 47          2.0                       4.0  55.0  ...                 87.0
# 48          2.0                       3.0  68.0  ...                 83.0
# 49          2.0                       3.0  76.0  ...                 73.0
#
#     defending_marking_awareness  defending_standing_tackle  \
# 30                         25.0                       25.0
# 31                         25.0                       36.0
# 32                         25.0                       25.0
# 33                         35.0                       55.0
# 34                         25.0                       25.0
# 35                         25.0                       25.0
# 36                         79.0                       87.0
# 37                         25.0                       22.0
# 38                         24.0                       45.0
# 39                         28.0                       39.0
# 40                         75.0                       83.0
# 41                         44.0                       63.0
# 42                         82.0                       84.0
# 43                         78.0                       84.0
# 44                         25.0                       29.0
# 45                         25.0                       25.0
# 46                         43.0                       59.0
# 47                         74.0                       81.0
# 48                         75.0                       85.0
# 49                         89.0                       87.0
#
#     defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 30                      25.0                84.0                  87.0
# 31                      30.0                15.0                  15.0
# 32                      25.0                83.0                  84.0
# 33                      55.0                 4.0                   2.0
# 34                      25.0                13.0                  11.0
# 35                      25.0                86.0                  81.0
# 36                      88.0                 5.0                  12.0
# 37                      25.0                 9.0                  10.0
# 38                      27.0                12.0                   5.0
# 39                      34.0                11.0                  13.0
# 40                      89.0                 4.0                   2.0
# 41                      59.0                10.0                  11.0
# 42                      86.0                 7.0                  12.0
# 43                      79.0                 5.0                   8.0
# 44                      26.0                14.0                   7.0
# 45                      25.0                87.0                  79.0
# 46                      63.0                 5.0                   4.0
# 47                      70.0                 7.0                   8.0
# 48                      83.0                10.0                   7.0
# 49                      87.0                 3.0                   3.0
#
#     goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 30                 69.0                     86.0                  88.0
# 31                 15.0                      5.0                  14.0
# 32                 73.0                     83.0                  84.0
# 33                  3.0                      2.0                   4.0
# 34                  5.0                      5.0                   7.0
# 35                 71.0                     81.0                  88.0
# 36                  9.0                     11.0                   8.0
# 37                 14.0                      5.0                   8.0
# 38                 13.0                     13.0                  10.0
# 39                 12.0                      8.0                  11.0
# 40                  4.0                      2.0                   4.0
# 41                 13.0                      7.0                  10.0
# 42                 15.0                      6.0                   5.0
# 43                 13.0                      9.0                  13.0
# 44                 12.0                      6.0                  10.0
# 45                 67.0                     79.0                  88.0
# 46                  1.0                      5.0                   2.0
# 47                 10.0                     10.0                  10.0
# 48                 13.0                     10.0                   9.0
# 49                  2.0                      4.0                   3.0
#
#     goalkeeping_speed
# 30               49.0
# 31               77.0
# 32               49.0
# 33               84.0
# 34               82.0
# 35               64.0
# 36               51.0
# 37               73.0
# 38               77.0
# 39               80.0
# 40               76.0
# 41               57.0
# 42               75.0
# 43               54.0
# 44               78.0
# 45               64.0
# 46               42.0
# 47               53.0
# 48               67.0
# 49               74.0
#
# [20 rows x 50 columns]

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161583 entries, 0 to 161582
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   overall                      161583 non-null  float64
#  1   potential                    161583 non-null  float64
#  2   value_eur                    161583 non-null  float64
#  3   age                          161583 non-null  float64
#  4   height_cm                    161583 non-null  float64
#  5   weight_kg                    161583 non-null  float64
#  6   weak_foot                    161583 non-null  float64
#  7   skill_moves                  161583 non-null  float64
#  8   international_reputation     161583 non-null  float64
#  9   pace                         161583 non-null  float64
#  10  shooting                     161583 non-null  float64
#  11  passing                      161583 non-null  float64
#  12  dribbling                    161583 non-null  float64
#  13  defending                    161583 non-null  float64
#  14  physic                       161583 non-null  float64
#  15  attacking_crossing           161583 non-null  float64
#  16  attacking_finishing          161583 non-null  float64
#  17  attacking_heading_accuracy   161583 non-null  float64
#  18  attacking_short_passing      161583 non-null  float64
#  19  attacking_volleys            161583 non-null  float64
#  20  skill_dribbling              161583 non-null  float64
#  21  skill_curve                  161583 non-null  float64
#  22  skill_fk_accuracy            161583 non-null  float64
#  23  skill_long_passing           161583 non-null  float64
#  24  skill_ball_control           161583 non-null  float64
#  25  movement_acceleration        161583 non-null  float64
#  26  movement_sprint_speed        161583 non-null  float64
#  27  movement_agility             161583 non-null  float64
#  28  movement_reactions           161583 non-null  float64
#  29  movement_balance             161583 non-null  float64
#  30  power_shot_power             161583 non-null  float64
#  31  power_jumping                161583 non-null  float64
#  32  power_stamina                161583 non-null  float64
#  33  power_strength               161583 non-null  float64
#  34  power_long_shots             161583 non-null  float64
#  35  mentality_aggression         161583 non-null  float64
#  36  mentality_interceptions      161583 non-null  float64
#  37  mentality_positioning        161583 non-null  float64
#  38  mentality_vision             161583 non-null  float64
#  39  mentality_penalties          161583 non-null  float64
#  40  mentality_composure          161583 non-null  float64
#  41  defending_marking_awareness  161583 non-null  float64
#  42  defending_standing_tackle    161583 non-null  float64
#  43  defending_sliding_tackle     161583 non-null  float64
#  44  goalkeeping_diving           161583 non-null  float64
#  45  goalkeeping_handling         161583 non-null  float64
#  46  goalkeeping_kicking          161583 non-null  float64
#  47  goalkeeping_positioning      161583 non-null  float64
#  48  goalkeeping_reflexes         161583 non-null  float64
#  49  goalkeeping_speed            161583 non-null  float64
# dtypes: float64(50)
# memory usage: 61.6 MB

# %%
non_numeric
# Out:
#        preferred_foot      work_rate         body_type real_face  \
# 0                Left     Medium/Low     Normal (170-)       Yes
# 1               Right       High/Low     Normal (185+)       Yes
# 2                Left       High/Low  Normal (170-185)       Yes
# 3               Right     Medium/Low     Normal (185+)       Yes
# 4               Right  Medium/Medium     Normal (185+)       Yes
# ...               ...            ...               ...       ...
# 161578          Right  Medium/Medium    Lean (170-185)        No
# 161579           Left  Medium/Medium     Normal (185+)        No
# 161580          Right    High/Medium  Normal (170-185)        No
# 161581          Right  Medium/Medium  Normal (170-185)        No
# 161582          Right  Medium/Medium    Lean (170-185)        No
#
#                                               player_tags  \
# 0       #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1       #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2       #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3       #Poacher, #Aerial Threat, #Distance Shooter, #...
# 4                                                     NaN
# ...                                                   ...
# 161578                                                NaN
# 161579                                                NaN
# 161580                                                NaN
# 161581                                                NaN
# 161582                                                NaN
#
#                                             player_traits
# 0       Finesse Shot, Speed Dribbler (AI), One Club Pl...
# 1       Power Free-Kick, Flair, Long Shot Taker (AI), ...
# 2       Diver, Injury Prone, Avoids Using Weaker Foot,...
# 3       Power Free-Kick, Leadership, Flair, Long Shot ...
# 4           GK Up for Corners, GK Long Throw, 1-on-1 Rush
# ...                                                   ...
# 161578                                                NaN
# 161579                                                NaN
# 161580                                                NaN
# 161581                                                NaN
# 161582                                                NaN
#
# [161583 rows x 6 columns]

# %%
#dropping the columns that have 30% missing values
n = []
n_less = []
for i in non_numeric.columns:
    if(non_numeric[i].isnull().sum()<(0.3*non_numeric.shape[0])):
        n.append(i)
    else:
        n_less.append(i)
non_numeric= non_numeric[n]

# %%
#filling the NaNs in the columns with the forward fill method
non_numeric.ffill()
# Out:
#        preferred_foot      work_rate         body_type real_face
# 0                Left     Medium/Low     Normal (170-)       Yes
# 1               Right       High/Low     Normal (185+)       Yes
# 2                Left       High/Low  Normal (170-185)       Yes
# 3               Right     Medium/Low     Normal (185+)       Yes
# 4               Right  Medium/Medium     Normal (185+)       Yes
# ...               ...            ...               ...       ...
# 161578          Right  Medium/Medium    Lean (170-185)        No
# 161579           Left  Medium/Medium     Normal (185+)        No
# 161580          Right    High/Medium  Normal (170-185)        No
# 161581          Right  Medium/Medium  Normal (170-185)        No
# 161582          Right  Medium/Medium    Lean (170-185)        No
#
# [161583 rows x 4 columns]

# %%
non_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161583 entries, 0 to 161582
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   preferred_foot  161583 non-null  object
#  1   work_rate       161583 non-null  object
#  2   body_type       161583 non-null  object
#  3   real_face       161583 non-null  object
# dtypes: object(4)
# memory usage: 4.9+ MB

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
#encoding the columns
label = LabelEncoder()

#creating a for loop to encode each column
for i in non_numeric.columns:
    non_numeric[i] = label.fit_transform(non_numeric[i])

non_numeric
# Out:
# C:\Users\edusa\AppData\Local\Temp\ipykernel_25032\1627849230.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_numeric[i] = label.fit_transform(non_numeric[i])
# C:\Users\edusa\AppData\Local\Temp\ipykernel_25032\1627849230.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_numeric[i] = label.fit_transform(non_numeric[i])
# C:\Users\edusa\AppData\Local\Temp\ipykernel_25032\1627849230.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_numeric[i] = label.fit_transform(non_numeric[i])
# C:\Users\edusa\AppData\Local\Temp\ipykernel_25032\1627849230.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_numeric[i] = label.fit_transform(non_numeric[i])
#         preferred_foot  work_rate  body_type  real_face
# 0                    0          7          3          1
# 1                    1          1          5          1
# 2                    0          1          4          1
# 3                    1          7          5          1
# 4                    1          8          5          1
# ...                ...        ...        ...        ...
# 161578               1          8          1          0
# 161579               0          8          5          0
# 161580               1          2          4          0
# 161581               1          8          4          0
# 161582               1          8          1          0
#
# [161583 rows x 4 columns]

# %%
#putting the numeric and non_numeric data together
df = pd.concat((numeric_data, non_numeric), axis = 1)
df
# Out:
#         overall  potential    value_eur   age  height_cm  weight_kg  \
# 0          93.0       95.0  100500000.0  27.0      169.0       67.0
# 1          92.0       92.0   79000000.0  29.0      185.0       80.0
# 2          90.0       90.0   54500000.0  30.0      180.0       80.0
# 3          90.0       90.0   52500000.0  32.0      195.0       95.0
# 4          90.0       90.0   63500000.0  28.0      193.0       92.0
# ...         ...        ...          ...   ...        ...        ...
# 161578     46.0       61.0     110000.0  18.0      180.0       73.0
# 161579     46.0       58.0     110000.0  19.0      188.0       83.0
# 161580     46.0       58.0     110000.0  19.0      181.0       73.0
# 161581     46.0       70.0     150000.0  17.0      175.0       68.0
# 161582     46.0       63.0     110000.0  17.0      180.0       70.0
#
#         weak_foot  skill_moves  international_reputation  pace  ...  \
# 0             3.0          4.0                       5.0  93.0  ...
# 1             4.0          5.0                       5.0  93.0  ...
# 2             2.0          4.0                       5.0  93.0  ...
# 3             4.0          4.0                       5.0  76.0  ...
# 4             4.0          1.0                       5.0  60.0  ...
# ...           ...          ...                       ...   ...  ...
# 161578        3.0          2.0                       1.0  63.0  ...
# 161579        3.0          2.0                       1.0  55.0  ...
# 161580        2.0          2.0                       1.0  65.0  ...
# 161581        3.0          2.0                       1.0  55.0  ...
# 161582        3.0          2.0                       1.0  61.0  ...
#
#         goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                      6.0                  11.0                 15.0
# 1                      7.0                  11.0                 15.0
# 2                     10.0                   8.0                 11.0
# 3                     13.0                  15.0                 10.0
# 4                     87.0                  85.0                 92.0
# ...                    ...                   ...                  ...
# 161578                 9.0                  13.0                 13.0
# 161579                 6.0                  14.0                  8.0
# 161580                 8.0                   9.0                  7.0
# 161581                13.0                  12.0                 14.0
# 161582                13.0                   7.0                  6.0
#
#         goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 0                          14.0                   8.0               91.0
# 1                          14.0                  11.0               91.0
# 2                           5.0                  15.0               91.0
# 3                           9.0                  12.0               74.0
# 4                          90.0                  86.0               60.0
# ...                         ...                   ...                ...
# 161578                     12.0                   7.0               63.0
# 161579                     13.0                  14.0               54.0
# 161580                     14.0                   9.0               64.0
# 161581                      7.0                  13.0               55.0
# 161582                      6.0                  14.0               60.0
#
#         preferred_foot  work_rate  body_type  real_face
# 0                    0          7          3          1
# 1                    1          1          5          1
# 2                    0          1          4          1
# 3                    1          7          5          1
# 4                    1          8          5          1
# ...                ...        ...        ...        ...
# 161578               1          8          1          0
# 161579               0          8          5          0
# 161580               1          2          4          0
# 161581               1          8          4          0
# 161582               1          8          1          0
#
# [161583 rows x 54 columns]

# %%
print(np.isnan(df).sum())  # Should output 0 if there are no NaN values
# Out:
# overall                        0
# potential                      0
# value_eur                      0
# age                            0
# height_cm                      0
# weight_kg                      0
# weak_foot                      0
# skill_moves                    0
# international_reputation       0
# pace                           0
# shooting                       0
# passing                        0
# dribbling                      0
# defending                      0
# physic                         0
# attacking_crossing             0
# attacking_finishing            0
# attacking_heading_accuracy     0
# attacking_short_passing        0
# attacking_volleys              0
# skill_dribbling                0
# skill_curve                    0
# skill_fk_accuracy              0
# skill_long_passing             0
# skill_ball_control             0
# movement_acceleration          0
# movement_sprint_speed          0
# movement_agility               0
# movement_reactions             0
# movement_balance               0
# power_shot_power               0
# power_jumping                  0
# power_stamina                  0
# power_strength                 0
# power_long_shots               0
# mentality_aggression           0
# mentality_interceptions        0
# mentality_positioning          0
# mentality_vision               0
# mentality_penalties            0
# mentality_composure            0
# defending_marking_awareness    0
# defending_standing_tackle      0
# defending_sliding_tackle       0
# goalkeeping_diving             0
# goalkeeping_handling           0
# goalkeeping_kicking            0
# goalkeeping_positioning        0
# goalkeeping_reflexes           0
# goalkeeping_speed              0
# preferred_foot                 0
# work_rate                      0
# body_type                      0
# real_face                      0
# dtype: int64

# %%
original_y = df['overall']

# %%
df.drop('overall', axis=1 , inplace=True)
original_x = df

# %%
#scaling the original matrix
scaler = StandardScaler()
original_X =  scaler.fit_transform(original_x)

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(original_X, original_y,test_size=0.2,random_state=42)

# %%
Xtrain = pd.DataFrame(Xtrain, columns=df.columns)

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize and train the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(Xtrain, Ytrain)

# Get feature importances
feature_importances = rf_model.feature_importances_

# Create a DataFrame for visualization
feature_importance_df = pd.DataFrame({
    'Feature': Xtrain.columns, 
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# %%
feature_importance_df
# Out:
#                         Feature  Importance
# 1                     value_eur    0.801629
# 2                           age    0.081236
# 0                     potential    0.047356
# 27           movement_reactions    0.023420
# 12                    defending    0.008986
# 11                    dribbling    0.003938
# 7      international_reputation    0.003226
# 23           skill_ball_control    0.003044
# 43           goalkeeping_diving    0.002595
# 46      goalkeeping_positioning    0.002184
# 47         goalkeeping_reflexes    0.002077
# 9                      shooting    0.001811
# 14           attacking_crossing    0.001456
# 13                       physic    0.001273
# 36        mentality_positioning    0.001033
# 10                      passing    0.000988
# 31                power_stamina    0.000985
# 39          mentality_composure    0.000797
# 44         goalkeeping_handling    0.000774
# 29             power_shot_power    0.000689
# 16   attacking_heading_accuracy    0.000633
# 17      attacking_short_passing    0.000570
# 42     defending_sliding_tackle    0.000509
# 33             power_long_shots    0.000493
# 41    defending_standing_tackle    0.000484
# 32               power_strength    0.000480
# 34         mentality_aggression    0.000460
# 25        movement_sprint_speed    0.000452
# 35      mentality_interceptions    0.000451
# 19              skill_dribbling    0.000413
# 37             mentality_vision    0.000402
# 40  defending_marking_awareness    0.000389
# 15          attacking_finishing    0.000379
# 24        movement_acceleration    0.000375
# 22           skill_long_passing    0.000335
# 30                power_jumping    0.000334
# 18            attacking_volleys    0.000315
# 38          mentality_penalties    0.000313
# 20                  skill_curve    0.000299
# 45          goalkeeping_kicking    0.000285
# 26             movement_agility    0.000282
# 8                          pace    0.000270
# 21            skill_fk_accuracy    0.000260
# 4                     weight_kg    0.000254
# 28             movement_balance    0.000251
# 48            goalkeeping_speed    0.000241
# 3                     height_cm    0.000221
# 51                    body_type    0.000106
# 50                    work_rate    0.000084
# 5                     weak_foot    0.000068
# 6                   skill_moves    0.000048
# 49               preferred_foot    0.000030
# 52                    real_face    0.000016

# %% [markdown]
# #### Create a subset of important features

# %%
# Set the number of top features to select
k = 10

# Select the top-k features
top_k_features = feature_importance_df.head(k)['Feature']


#The important features
print(top_k_features)
# Out:
# 1                    value_eur
# 2                          age
# 0                    potential
# 27          movement_reactions
# 12                   defending
# 11                   dribbling
# 7     international_reputation
# 23          skill_ball_control
# 43          goalkeeping_diving
# 46     goalkeeping_positioning
# Name: Feature, dtype: object

# %%
#selecting the top features from the original dataframe
selected_features = df[top_k_features]
selected_features
# Out:
#           value_eur   age  potential  movement_reactions  defending  \
# 0       100500000.0  27.0       95.0                94.0       27.0
# 1        79000000.0  29.0       92.0                90.0       32.0
# 2        54500000.0  30.0       90.0                89.0       32.0
# 3        52500000.0  32.0       90.0                85.0       34.0
# 4        63500000.0  28.0       90.0                89.0       26.0
# ...             ...   ...        ...                 ...        ...
# 161578     110000.0  18.0       61.0                39.0       24.0
# 161579     110000.0  19.0       58.0                42.0       48.0
# 161580     110000.0  19.0       58.0                50.0       43.0
# 161581     150000.0  17.0       70.0                45.0       20.0
# 161582     110000.0  17.0       63.0                40.0       45.0
#
#         dribbling  international_reputation  skill_ball_control  \
# 0            96.0                       5.0                96.0
# 1            91.0                       5.0                92.0
# 2            92.0                       5.0                90.0
# 3            86.0                       5.0                90.0
# 4            33.0                       5.0                31.0
# ...           ...                       ...                 ...
# 161578       47.0                       1.0                45.0
# 161579       34.0                       1.0                32.0
# 161580       46.0                       1.0                35.0
# 161581       46.0                       1.0                43.0
# 161582       32.0                       1.0                31.0
#
#         goalkeeping_diving  goalkeeping_positioning
# 0                      6.0                     14.0
# 1                      7.0                     14.0
# 2                     10.0                      5.0
# 3                     13.0                      9.0
# 4                     87.0                     90.0
# ...                    ...                      ...
# 161578                 9.0                     12.0
# 161579                 6.0                     13.0
# 161580                 8.0                     14.0
# 161581                13.0                      7.0
# 161582                13.0                      6.0
#
# [161583 rows x 10 columns]

# %% [markdown]
# #### Creating and training Ensemble Models

# %%
import pickle
filename = 'scaler.pkl'
pickle.dump(scaler, open(filename, 'wb'))

# %%
X = selected_features

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X, original_y,test_size=0.2,random_state=42)

# %%
# MODEL  1      -  RANDOM   FOREST   REGRESSOR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Initialize the Random Forest Regressor model
rf_model = RandomForestRegressor(random_state=42)

# Train the model on the training data
rf_model.fit(Xtrain, Ytrain)

# Predictions on the validation set
predictions = rf_model.predict(Xtest)

# Evaluate the model
mae = mean_absolute_error(Ytest, predictions)
rmse = np.sqrt(mean_squared_error(Ytest, predictions))
r2 = r2_score(Ytest, predictions)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Absolute Error: 0.50
# Root Mean Squared Error: 0.84
# R-squared: 0.99

# %%
# MODEL  2      -     GRADIENT   BOOSTING   REGRESSOR
from sklearn.ensemble import GradientBoostingRegressor


# Initialize the model
gb_model = GradientBoostingRegressor(random_state=42)


# Train the model on the training data
gb_model.fit(Xtrain, Ytrain)


# Predictions on the validation set
predictions = gb_model.predict(Xtest)

# Evaluate the model
mae = mean_absolute_error(Ytest, predictions)
rmse = np.sqrt(mean_squared_error(Ytest, predictions))
r2 = r2_score(Ytest, predictions)


print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Absolute Error: 0.93
# Root Mean Squared Error: 1.23
# R-squared: 0.97

# %%
# MODEL  3 - XG   BOOST   REGRESSOR

from xgboost import XGBRegressor

# Initialize the model
xgb_model = XGBRegressor(random_state=42)

# Train the model on the training data
xgb_model.fit(Xtrain, Ytrain)


# Predictions on the validation set
predictions = xgb_model.predict(Xtest)

# Evaluate the model
mae = mean_absolute_error(Ytest, predictions)
rmse = np.sqrt(mean_squared_error(Ytest, predictions))
r2 = r2_score(Ytest, predictions)


print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Absolute Error: 0.67
# Root Mean Squared Error: 0.95
# R-squared: 0.98

# %%
# MODEL  4 - ADA   BOOST  REGRESSOR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Initialize the AdaBoost Regressor model
adb_model = AdaBoostRegressor(random_state=42)

# Train the model on the training data
adb_model.fit(Xtrain, Ytrain)

# Predictions on the validation set
predictions = adb_model.predict(Xtest)

# Evaluate the model
mae = mean_absolute_error(Ytest, predictions)
rmse = np.sqrt(mean_squared_error(Ytest, predictions))
r2 = r2_score(Ytest, predictions)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Absolute Error: 1.70
# Root Mean Squared Error: 2.04
# R-squared: 0.92

# %% [markdown]
# #### Cross-Validation to get the Best Ensemble model

# %%
from sklearn.model_selection import GridSearchCV, KFold

# %%
# Define parameters for grid search
param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5]
}

param_grid_gb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.1, 0.05]
}

param_grid_xgb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.1, 0.05],
    'max_depth': [3, 5, 7]
}

param_grid_ada = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [1.0, 0.5, 0.1]
}

# %%
# Initialize KFold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Initialize GridSearchCV for Random Forest
grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid_rf, cv=kf, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search_rf.fit(Xtrain, Ytrain)

# Initialize GridSearchCV for Gradient Boosting
grid_search_gb = GridSearchCV(estimator=gb_model, param_grid=param_grid_gb, cv=kf, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search_gb.fit(Xtrain, Ytrain)

# Initialize GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb, cv=kf, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search_xgb.fit(Xtrain, Ytrain)

# Initialize GridSearchCV for AdaBoost
grid_search_ada = GridSearchCV(estimator=adb_model, param_grid=param_grid_ada, cv=kf, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search_ada.fit(Xtrain, Ytrain)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=AdaBoostRegressor(random_state=42), n_jobs=-1,
#              param_grid={'learning_rate': [1.0, 0.5, 0.1],
#                          'n_estimators': [50, 100, 200]},
#              scoring='neg_mean_squared_error')

# %%
# Get best parameters for Random Forest
best_params_rf = grid_search_rf.best_params_

# Train Random Forest with best parameters
best_rf_model = RandomForestRegressor(**best_params_rf, random_state=42)
best_rf_model.fit(Xtrain, Ytrain)

# Predict and evaluate on validation set
y_pred_rf = best_rf_model.predict(Xtest)
mae_rf = mean_absolute_error(Ytest, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(Ytest, y_pred_rf))
r2_rf = r2_score(Ytest, y_pred_rf)

print("Random Forest Regressor")
print(f"Mean Absolute Error: {mae_rf:.2f}")
print(f"Root Mean Squared Error: {rmse_rf:.2f}")
print(f"R-squared: {r2_rf:.2f}")

# Get best parameters for Gradient Boosting
best_params_gb = grid_search_gb.best_params_

# Train Gradient Boosting with best parameters
best_gb_model = GradientBoostingRegressor(**best_params_gb, random_state=42)
best_gb_model.fit(Xtrain, Ytrain)

# Predict and evaluate on validation set
y_pred_gb = best_gb_model.predict(Xtest)
mae_gb = mean_absolute_error(Ytest, y_pred_gb)
rmse_gb = np.sqrt(mean_squared_error(Ytest, y_pred_gb))
r2_gb = r2_score(Ytest, y_pred_gb)

print("Gradient Boosting Regressor")
print(f"Mean Absolute Error: {mae_gb:.2f}")
print(f"Root Mean Squared Error: {rmse_gb:.2f}")
print(f"R-squared: {r2_gb:.2f}")

# Get best parameters for XGBoost
best_params_xgb = grid_search_xgb.best_params_

# Train XGBoost with best parameters
best_xgb_model = XGBRegressor(**best_params_xgb, random_state=42)
best_xgb_model.fit(Xtrain, Ytrain)

# Predict and evaluate on the test set
y_pred_xgb = best_xgb_model.predict(Xtest)
mae_xgb = mean_absolute_error(Ytest, y_pred_xgb)
rmse_xgb= np.sqrt(mean_squared_error(Ytest, y_pred_xgb))
r2_xgb = r2_score(Ytest, y_pred_xgb)

print("XGB Boost Regressor")
print(f"Mean Absolute Error: {mae_xgb:.2f}")
print(f"Root Mean Squared Error: {rmse_xgb:.2f}")
print(f"R-squared: {r2_xgb:.2f}")


# Get best parameters for AdaBoost
best_params_ada = grid_search_ada.best_params_

# Train AdaBoost with best parameters
best_ada_model = AdaBoostRegressor(**best_params_ada, random_state=42)
best_ada_model.fit(Xtrain, Ytrain)

# Predict and evaluate on the test set
y_pred_ada = best_ada_model.predict(Xtest)
mae_ada = mean_absolute_error(Ytest, y_pred_ada)
rmse_ada = np.sqrt(mean_squared_error(Ytest, y_pred_ada))
r2_ada = r2_score(Ytest, y_pred_ada)

print("Ada Boost Regressor")
print(f"Mean Absolute Error: {mae_ada:.2f}")
print(f"Root Mean Squared Error: {rmse_ada:.2f}")
print(f"R-squared: {r2_ada:.2f}")
# Out:
# Random Forest Regressor
# Mean Absolute Error: 0.50
# Root Mean Squared Error: 0.83
# R-squared: 0.99
# Gradient Boosting Regressor
# Mean Absolute Error: 0.83
# Root Mean Squared Error: 1.10
# R-squared: 0.98
# XGB Boost Regressor
# Mean Absolute Error: 0.62
# Root Mean Squared Error: 0.91
# R-squared: 0.98
# Ada Boost Regressor
# Mean Absolute Error: 1.61
# Root Mean Squared Error: 2.01
# R-squared: 0.92

# %%
# Compare XGBoost and AdaBoost
if rmse_xgb < rmse_ada:
    best_ensemble_model = best_xgb_model
    best_ensemble_params = best_params_xgb
    best_ensemble_rmse = rmse_xgb
else:
    best_ensemble_model = best_ada_model
    best_ensemble_params = best_params_ada
    best_ensemble_rmse = rmse_ada

# Compare Random Forest and Gradient Boosting
if rmse_rf < rmse_gb:
    best_forest_model = best_rf_model
    best_forest_params = best_params_rf
    best_forest_rmse = rmse_rf
else:
    best_forest_model = best_gb_model
    best_forest_params = best_params_gb
    best_forest_rmse = rmse_gb

# Compare the best models from each category
if best_ensemble_rmse < best_forest_rmse:
    best_model = best_ensemble_model
    best_params = best_ensemble_params
    best_mse = best_ensemble_rmse
else:
    best_model = best_forest_model
    best_params = best_forest_params
    best_mse = best_forest_rmse


# Evaluate on test set
y_pred_test = best_model.predict(Xtest)
mse_test = mean_squared_error(Ytest, y_pred_test)

print("Best Model:", best_model)
print("Best Hyperparameters:", best_params)
print("MSE on Test Set:", mse_test)
# Out:
# Best Model: RandomForestRegressor(n_estimators=200, random_state=42)
# Best Hyperparameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
# MSE on Test Set: 0.6941692421945107

# %%
y_pred_test
# Out:
# array([62.23 , 64.5  , 68.05 , ..., 56.06 , 63.545, 52.68 ])

# %%
#Saving Model as File
import pickle
filename = 'model.pkl'
pickle.dump(rf_model, open(filename , 'wb'))

# %% [markdown]
# ## Using the data from Players_22 data

# %%
players_22_testing.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)

# %% [markdown]
# ### Data Cleaning

# %%
selected_columns_test = ['overall','potential','value_eur','defending','dribbling','movement_reactions','international_reputation','skill_ball_control','goalkeeping_diving','goalkeeping_positioning','age']
test_columns = players_22_testing[selected_columns_test]
test_columns
# Out:
#        overall  potential    value_eur  defending  dribbling  \
# 0           93         93   78000000.0       34.0       95.0
# 1           92         92  119500000.0       44.0       86.0
# 2           91         91   45000000.0       34.0       88.0
# 3           91         91  129000000.0       37.0       94.0
# 4           91         91  125500000.0       64.0       88.0
# ...        ...        ...          ...        ...        ...
# 19234       47         52      70000.0       42.0       48.0
# 19235       47         59     110000.0       41.0       46.0
# 19236       47         55     100000.0       41.0       49.0
# 19237       47         60     110000.0       15.0       48.0
# 19238       47         60     110000.0       36.0       48.0
#
#        movement_reactions  international_reputation  skill_ball_control  \
# 0                      94                         5                  96
# 1                      93                         5                  88
# 2                      94                         5                  88
# 3                      89                         5                  95
# 4                      91                         4                  91
# ...                   ...                       ...                 ...
# 19234                  53                         1                  49
# 19235                  49                         1                  42
# 19236                  46                         1                  49
# 19237                  48                         1                  45
# 19238                  54                         1                  38
#
#        goalkeeping_diving  goalkeeping_positioning  age
# 0                       6                       14   34
# 1                      15                        8   32
# 2                       7                       14   36
# 3                       9                       15   29
# 4                      15                       10   30
# ...                   ...                      ...  ...
# 19234                   6                       15   22
# 19235                  11                        8   19
# 19236                   8                       10   21
# 19237                   7                       14   19
# 19238                   8                        9   19
#
# [19239 rows x 11 columns]

# %%
test_columns.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'defending', 'dribbling',
#        'movement_reactions', 'international_reputation', 'skill_ball_control',
#        'goalkeeping_diving', 'goalkeeping_positioning', 'age'],
#       dtype='object')

# %%
#creating a function to do data cleaning
def preprocess_data(df):
    """
    Preprocesses the data by performing the following steps:
    1. Drops columns with more than 30% missing values.
    2. Imputes missing values in numeric columns using IterativeImputer.
    3. Forward fills missing values in non-numeric columns.
    4. Encodes non-numeric columns using LabelEncoder.
    5. Concatenates the processed numeric and non-numeric data back together.

    Parameters:
    df (pd.DataFrame): The input DataFrame to preprocess.

    Returns:
    pd.DataFrame: The preprocessed DataFrame.
    """
    
    # Dropping columns that have more than 30% missing values
    columns_to_keep = []
    columns_to_drop = []
    for col in df.columns:
        if df[col].isnull().sum() < (0.3 * df.shape[0]):
            columns_to_keep.append(col)
        else:
            columns_to_drop.append(col)

    df = df[columns_to_keep]

    # Separating numeric and non-numeric data
    numeric_data = df.select_dtypes(include=np.number)
    non_numeric_data = df.select_dtypes(exclude=np.number)

    # Imputing missing values in numeric data
    imp = IterativeImputer(max_iter=10, tol=1e-1, random_state=0)
    numeric_data_imputed = imp.fit_transform(numeric_data)
    numeric_data = pd.DataFrame(np.round(numeric_data_imputed), columns=numeric_data.columns)

    # Dropping columns in non-numeric data that have more than 30% missing values
    non_numeric_data = non_numeric_data.loc[:, non_numeric_data.isnull().mean() < 0.3]

    # Filling NaNs in non-numeric data with forward fill method
    non_numeric_data.ffill(inplace=True)

    # Encoding non-numeric columns
    label_encoder = LabelEncoder()
    for col in non_numeric_data.columns:
        non_numeric_data[col] = label_encoder.fit_transform(non_numeric_data[col])

    # Concatenating the numeric and non-numeric data back together
    df_processed = pd.concat([numeric_data, non_numeric_data], axis=1)
    
    return df_processed

# Usage:
df_processed = preprocess_data(test_columns)

# %% [markdown]
# ### Model Training

# %%
#creating our y and X
yt = df_processed['overall']
df_processed.drop('overall', axis=1 , inplace=True)
Xt = df_processed

# %%
Xt.columns
# Out:
# Index(['potential', 'value_eur', 'defending', 'dribbling',
#        'movement_reactions', 'international_reputation', 'skill_ball_control',
#        'goalkeeping_diving', 'goalkeeping_positioning', 'age'],
#       dtype='object')

# %%
#scaling the data down
scaled_feature_test = scaler.fit_transform(Xt)
scaled_test = pd.DataFrame(Xt, columns=Xt.columns)

#Train Split
Xt_train, Xt_test, yt_train, yt_test = train_test_split(Xt, yt, test_size=0.2, random_state=42)
rf_model.fit(Xt_train, yt_train)

# Predictions on the validation set
predictions_22 = rf_model.predict(Xt_test)

# Evaluate the model
mae = mean_absolute_error(yt_test, predictions_22)
rmse = np.sqrt(mean_squared_error(yt_test, predictions_22))
r2 = r2_score(yt_test, predictions_22)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Absolute Error: 0.25
# Root Mean Squared Error: 0.52
# R-squared: 0.99

# %%
values = {"Ytest": yt_test, "Ypred": predictions_22}
df = pd.DataFrame(values)

df.to_csv('ytest-ypred.csv', index=False)
